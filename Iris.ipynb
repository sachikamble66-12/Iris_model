# %% [markdown]
# <a href="https://colab.research.google.com/github/sachikamble66-12/Iris_model/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Iris.csv')

# %%
data

# %%
data.info()

# %%
data.head()

# %%
data.tail()

# %%
data = data.dropna()

# %%
data.columns

# %%
data["Species"].value_counts()

# %%
y = data["Species"]

# %%
x = data.drop(columns=["Id","Species"])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
y_pred = model.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)

# %%
print(f"accuracy_scre : {acc}")

# %%
import joblib

# %%
joblib.dump(model, "iris_model.pkl")

# %%
from google.colab import drive
drive.mount('/content/drive')
